# %%
import numpy as np
import random
import mcts
from cards import *
from players import *
from game import *    
from random_policy import *
from decklists import *

# %%
# todo: handle generic mana debt
# todo: implement 7th or 8th ed starter 2 player decks
# todo: clean up and sexify code
#%%capture
player_0_wins = 0
player_1_wins = 0
for i in range(10):
    game = Game(Player(get_bear_wars_deck()), Player(get_bear_wars_deck()))
    game.start_game()
    while not game.is_over():
        #print("Current Game Phase: %s"  % (game.phases[game.current_phase_index]))
        if game.player_with_priority.index is 0:
            move = game.player_with_priority.determine_move(method="random", game=game)
        else:
            if True: #game.phases[game.current_phase_index] == "Declare Attackers Step":
                if len(game.get_moves()) == 1:
                    move = game.get_moves()[0]
                else:
                    move = mcts.uct(game, itermax = 10)
            else:
                move = game.player_with_priority.determine_move(method="random", game=game)
        game.make_move(move)    
    for j in range(2):
        print(game.get_legal_moves(game.players[j]))
    player_0_wins += game.players[0].wins
    player_1_wins += game.players[1].wins
    print("game is over! current standings: %i - %i" % (player_0_wins, player_1_wins))
print("player 0 wins: %i, player 1 wins: %i" % (player_0_wins, player_1_wins))
# Out:
# player 0 goes first
# []
# []
# game is over! current standings: 0 - 1
# player 0 goes first
# []
# []
# game is over! current standings: 0 - 2
# player 1 goes first
# []
# []
# game is over! current standings: 0 - 3
# player 0 goes first
# []
# []
# game is over! current standings: 0 - 4
# player 0 goes first
# []
# []
# game is over! current standings: 0 - 5
# player 1 goes first
# []
# []
# game is over! current standings: 1 - 5
# player 1 goes first
# []
# []
# game is over! current standings: 1 - 6
# player 1 goes first
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-1ed33ab213cb> in <module>()
#      19                     move = game.get_moves()[0]
#      20                 else:
# ---> 21                     move = mcts.uct(game, itermax = 10)
#      22             else:
#      23                 move = game.player_with_priority.determine_move(method="random", game=game)
#
# /home/hlynurd/Notebook/open-mtg/mcts.py in uct(rootstate, itermax, verbose)
#      56     for i in range(itermax):
#      57         node = rootnode
# ---> 58         state = copy.deepcopy(rootstate)
#      59         # mtg fix: shuffle own deck
#      60         state.players[node.player_just_moved.index].shuffle_deck()
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     180                             raise Error(
#     181                                 "un(deep)copyable object of type %s" % cls)
# --> 182                 y = _reconstruct(x, rv, 1, memo)
#     183
#     184     # If is its own copy, don't memoize.
#
# /usr/lib/python3.5/copy.py in _reconstruct(x, info, deep, memo)
#     295     if state is not None:
#     296         if deep:
# --> 297             state = deepcopy(state, memo)
#     298         if hasattr(y, '__setstate__'):
#     299             y.__setstate__(state)
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /usr/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /usr/lib/python3.5/copy.py in _deepcopy_list(x, memo)
#     216     memo[id(x)] = y
#     217     for a in x:
# --> 218         y.append(deepcopy(a, memo))
#     219     return y
#     220 d[list] = _deepcopy_list
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     180                             raise Error(
#     181                                 "un(deep)copyable object of type %s" % cls)
# --> 182                 y = _reconstruct(x, rv, 1, memo)
#     183
#     184     # If is its own copy, don't memoize.
#
# /usr/lib/python3.5/copy.py in _reconstruct(x, info, deep, memo)
#     295     if state is not None:
#     296         if deep:
# --> 297             state = deepcopy(state, memo)
#     298         if hasattr(y, '__setstate__'):
#     299             y.__setstate__(state)
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /usr/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /usr/lib/python3.5/copy.py in _deepcopy_list(x, memo)
#     216     memo[id(x)] = y
#     217     for a in x:
# --> 218         y.append(deepcopy(a, memo))
#     219     return y
#     220 d[list] = _deepcopy_list
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     180                             raise Error(
#     181                                 "un(deep)copyable object of type %s" % cls)
# --> 182                 y = _reconstruct(x, rv, 1, memo)
#     183
#     184     # If is its own copy, don't memoize.
#
# /usr/lib/python3.5/copy.py in _reconstruct(x, info, deep, memo)
#     295     if state is not None:
#     296         if deep:
# --> 297             state = deepcopy(state, memo)
#     298         if hasattr(y, '__setstate__'):
#     299             y.__setstate__(state)
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /usr/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /usr/lib/python3.5/copy.py in _deepcopy_list(x, memo)
#     216     memo[id(x)] = y
#     217     for a in x:
# --> 218         y.append(deepcopy(a, memo))
#     219     return y
#     220 d[list] = _deepcopy_list
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     180                             raise Error(
#     181                                 "un(deep)copyable object of type %s" % cls)
# --> 182                 y = _reconstruct(x, rv, 1, memo)
#     183
#     184     # If is its own copy, don't memoize.
#
# /usr/lib/python3.5/copy.py in _reconstruct(x, info, deep, memo)
#     295     if state is not None:
#     296         if deep:
# --> 297             state = deepcopy(state, memo)
#     298         if hasattr(y, '__setstate__'):
#     299             y.__setstate__(state)
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /usr/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     180                             raise Error(
#     181                                 "un(deep)copyable object of type %s" % cls)
# --> 182                 y = _reconstruct(x, rv, 1, memo)
#     183
#     184     # If is its own copy, don't memoize.
#
# /usr/lib/python3.5/copy.py in _reconstruct(x, info, deep, memo)
#     295     if state is not None:
#     296         if deep:
# --> 297             state = deepcopy(state, memo)
#     298         if hasattr(y, '__setstate__'):
#     299             y.__setstate__(state)
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /usr/lib/python3.5/copy.py in _deepcopy_dict(x, memo)
#     241     memo[id(x)] = y
#     242     for key, value in x.items():
# --> 243         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     244     return y
#     245 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /usr/lib/python3.5/copy.py in _deepcopy_list(x, memo)
#     216     memo[id(x)] = y
#     217     for a in x:
# --> 218         y.append(deepcopy(a, memo))
#     219     return y
#     220 d[list] = _deepcopy_list
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     180                             raise Error(
#     181                                 "un(deep)copyable object of type %s" % cls)
# --> 182                 y = _reconstruct(x, rv, 1, memo)
#     183
#     184     # If is its own copy, don't memoize.
#
# /usr/lib/python3.5/copy.py in _reconstruct(x, info, deep, memo)
#     289         dictiter = None
#     290     if deep:
# --> 291         args = deepcopy(args, memo)
#     292     y = callable(*args)
#     293     memo[id(x)] = y
#
# /usr/lib/python3.5/copy.py in deepcopy(x, memo, _nil)
#     153     copier = _deepcopy_dispatch.get(cls)
#     154     if copier:
# --> 155         y = copier(x, memo)
#     156     else:
#     157         try:
#
# /usr/lib/python3.5/copy.py in _deepcopy_tuple(x, memo)
#     228     except KeyError:
#     229         pass
# --> 230     for k, j in zip(x, y):
#     231         if k is not j:
#     232             y = tuple(y)
#
# KeyboardInterrupt:
