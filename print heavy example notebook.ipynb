# %%
# coding: utf-8

# In[1]:

import mcts
from decklists import *
from game import *

player_0_wins = 0
player_1_wins = 0
prev_phase = ""
printed_attackers_blockers = False
attackers = False
        #self.phases = ["Main Phase", "Declare Attackers Step", "Declare Blockers Step", "509.2", "510.1c",
#                       "Combat Damage Step", "Main Phase", "End Step"]
for i in range(1):
    game = Game(Player(get_8ed_core_gold_deck()), Player(get_8ed_core_silver_deck()))
    game.start_game()
    if game.active_player.index == 0:
        print("Gold player's turn")
    else:
        print("Silver player's turn")
    while not game.is_over():
        if game.player_with_priority.index is 1:
            move = game.player_with_priority.determine_move(method="random", game=game)
        else:
            #            move = game.player_with_priority.determine_move(method="random", game=game)
            if len(game.get_moves()) == 1:
                move = game.get_moves()[0]
            else:
                move = mcts.uct(game, itermax=5)
                
        game.make_move(move, True)
        
        current_phase = game.phases[game.current_phase_index]
        if current_phase == "510.1c" and not printed_attackers_blockers:
            printed_attackers_blockers = True
            if len(game.attackers)>0:
                attackers = True
                print("  current phase is: %s" % (current_phase))
                print("    attacking creatures %s: " % (game.attackers))
            if len(game.blockers)>0:
                print("    blocking creatures %s: " % (game.blockers))
         
        if current_phase == "Combat Damage Step" and attackers:
            print("      Gold player's life: %i, Silver player's life: %i" %(game.players[0].life, game.players[1].life))
        if current_phase == "End Step":
            attackers = False
            printed_attackers_blockers = False
            gold_permanents = []
            silver_permanents = []
            for permanent in game.battlefield:
                if permanent.owner.index == 0:
                    gold_permanents.append(permanent)
                else:
                    silver_permanents.append(permanent)
            print("  current phase is: %s" % (current_phase))            
            if game.active_player.index == 0:
                print("    gold player's permanents: %s" % (gold_permanents))
                print("\nSilver player's turn ")
            else:
                
                print("    silver player's permanents: %s" % (silver_permanents))
                print("\nGold player's turn " )
        prev_phase = current_phase
    
    
    if game.players[1].has_lost:
        player_0_wins += 1
    elif game.players[0].has_lost:
        player_1_wins += 1
    print("game is over! current standings: %i - %i" % (player_0_wins, player_1_wins))
print("player 0 wins: %i, player 1 wins: %i" % (player_0_wins, player_1_wins))
# Out:
# Gold player's turn
#     playing Forest
#   current phase is: End Step
#     gold player's permanents: [Forest]
#
# Silver player's turn
#     playing Island
#   current phase is: End Step
#     silver player's permanents: [Island]
#
# Gold player's turn
#     playing Forest
#     casting Norwood Ranger
#   current phase is: End Step
#     gold player's permanents: [Forest, Forest, Norwood Ranger]
#
# Silver player's turn
#     playing Plains
#   current phase is: End Step
#     silver player's permanents: [Island, Plains]
#
# Gold player's turn
#     playing Mountain
#   current phase is: End Step
#     gold player's permanents: [Forest, Forest, Norwood Ranger, Mountain]
#
# Silver player's turn
#     playing Island
#     casting Glory Seeker
#   current phase is: End Step
#     silver player's permanents: [Island, Plains, Island, Glory Seeker]
#
# Gold player's turn
#   current phase is: 510.1c
#     attacking creatures [Norwood Ranger]:
#     blocking creatures [Glory Seeker]:
#       Gold player's life: 20, Silver player's life: 20
#     casting Goblin Raider
#   current phase is: End Step
#     gold player's permanents: [Forest, Forest, Mountain, Goblin Raider]
#
# Silver player's turn
#   current phase is: 510.1c
#     attacking creatures [Glory Seeker]:
#       Gold player's life: 18, Silver player's life: 20
#     playing Plains
#     casting Giant Octopus
#   current phase is: End Step
#     silver player's permanents: [Island, Plains, Island, Glory Seeker, Plains, Giant Octopus]
#
# Gold player's turn
#     casting Volcanic Hammer
#   current phase is: End Step
#     gold player's permanents: [Forest, Forest, Mountain, Goblin Raider]
#
# Silver player's turn
#     playing Island
#   current phase is: End Step
#     silver player's permanents: [Island, Plains, Island, Plains, Giant Octopus, Island]
#
# Gold player's turn
#     playing Forest
#     casting Stone Rain
#   current phase is: End Step
#     gold player's permanents: [Forest, Forest, Mountain, Goblin Raider, Forest]
#
# Silver player's turn
#     playing Island
#     casting Glory Seeker
#   current phase is: 510.1c
#     attacking creatures [Giant Octopus]:
#       Gold player's life: 15, Silver player's life: 20
#   current phase is: End Step
#     silver player's permanents: [Plains, Island, Plains, Giant Octopus, Island, Island, Glory Seeker]
#
# Gold player's turn
#   current phase is: 510.1c
#     attacking creatures [Goblin Raider]:
#     blocking creatures [Giant Octopus]:
#       Gold player's life: 15, Silver player's life: 20
#   current phase is: End Step
#     gold player's permanents: [Forest, Forest, Mountain, Forest]
#
# Silver player's turn
#     playing Island
#   current phase is: 510.1c
#     attacking creatures [Giant Octopus, Glory Seeker]:
#       Gold player's life: 10, Silver player's life: 20
#   current phase is: End Step
#     silver player's permanents: [Plains, Island, Plains, Giant Octopus, Island, Island, Glory Seeker, Island]
#
# Gold player's turn
#     casting Grizzly Bears
#     playing Mountain
#     casting Grizzly Bears
#   current phase is: End Step
#     gold player's permanents: [Forest, Forest, Mountain, Forest, Grizzly Bears, Mountain, Grizzly Bears]
#
# Silver player's turn
#     playing Plains
#   current phase is: End Step
#     silver player's permanents: [Plains, Island, Plains, Giant Octopus, Island, Island, Glory Seeker, Island, Plains]
#
# Gold player's turn
#     playing Mountain
#     casting Ogre Taskmaster
#   current phase is: 510.1c
#     attacking creatures [Grizzly Bears]:
#     blocking creatures [Giant Octopus, Glory Seeker]:
#       Gold player's life: 10, Silver player's life: 20
#   current phase is: End Step
#     gold player's permanents: [Forest, Forest, Mountain, Forest, Mountain, Grizzly Bears, Mountain, Ogre Taskmaster]
#
# Silver player's turn
#     playing Plains
#     casting Glory Seeker
#     casting Giant Octopus
#   current phase is: End Step
#     silver player's permanents: [Plains, Island, Plains, Island, Island, Glory Seeker, Island, Plains, Plains, Glory Seeker, Giant Octopus]
#
# Gold player's turn
#     casting Lava Axe
#   current phase is: 510.1c
#     attacking creatures [Ogre Taskmaster]:
#     blocking creatures [Glory Seeker]:
#       Gold player's life: 5, Silver player's life: 20
#   current phase is: End Step
#     gold player's permanents: [Forest, Forest, Mountain, Forest, Mountain, Grizzly Bears, Mountain, Ogre Taskmaster]
#
# Silver player's turn
#     playing Island
#   current phase is: 510.1c
#     attacking creatures [Glory Seeker, Giant Octopus]:
#     blocking creatures [Grizzly Bears]:
#       Gold player's life: 3, Silver player's life: 20
#   current phase is: End Step
#     silver player's permanents: [Plains, Island, Plains, Island, Island, Island, Plains, Plains, Glory Seeker, Giant Octopus, Island]
#
# Gold player's turn
#     playing Mountain
#     casting Enormous Baloth
#   current phase is: 510.1c
#     attacking creatures [Grizzly Bears, Ogre Taskmaster]:
#     blocking creatures [Giant Octopus]:
#       Gold player's life: 3, Silver player's life: 16
#   current phase is: End Step
#     gold player's permanents: [Forest, Forest, Mountain, Forest, Mountain, Mountain, Ogre Taskmaster, Mountain, Enormous Baloth]
#
# Silver player's turn
#     playing Plains
#     casting Vizzerdrix
#   current phase is: 510.1c
#     attacking creatures [Glory Seeker]:
#       Gold player's life: 1, Silver player's life: 16
#   current phase is: End Step
#     silver player's permanents: [Plains, Island, Plains, Island, Island, Island, Plains, Plains, Glory Seeker, Island, Plains, Vizzerdrix]
#
# Gold player's turn
#   current phase is: 510.1c
#     attacking creatures [Ogre Taskmaster]:
#     blocking creatures [Glory Seeker]:
#       Gold player's life: 1, Silver player's life: 16
#     casting Lava Axe
#     playing Mountain
#   current phase is: End Step
#     gold player's permanents: [Forest, Forest, Mountain, Forest, Mountain, Mountain, Mountain, Enormous Baloth, Mountain]
#
# Silver player's turn
#   current phase is: 510.1c
#     attacking creatures [Vizzerdrix]:
#     blocking creatures [Enormous Baloth]:
#       Gold player's life: 1, Silver player's life: 11
#   current phase is: End Step
#     silver player's permanents: [Plains, Island, Plains, Island, Island, Island, Plains, Plains, Island, Plains]
#
# Gold player's turn
#     playing Forest
#   current phase is: 510.1c
#     attacking creatures [Enormous Baloth]:
#       Gold player's life: 1, Silver player's life: 4
#   current phase is: End Step
#     gold player's permanents: [Forest, Forest, Mountain, Forest, Mountain, Mountain, Mountain, Enormous Baloth, Mountain, Forest]
#
# Silver player's turn
#     playing Plains
#   current phase is: End Step
#     silver player's permanents: [Plains, Island, Plains, Island, Island, Island, Plains, Plains, Island, Plains, Plains]
#
# Gold player's turn
#     casting Volcanic Hammer
#   current phase is: 510.1c
#     attacking creatures [Enormous Baloth]:
#       Gold player's life: 1, Silver player's life: -6
# game is over! current standings: 1 - 0
# player 0 wins: 1, player 1 wins: 0
